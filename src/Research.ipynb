# %%
from finviz.screener import Screener
from pytrials.client import ClinicalTrials
import pandas as pd
import datetime
import numpy as np

# %%
data = pd.read_csv('data/az_p3.csv')

# %%
data
# Out:
#      Rank   NCT Number                                              Title  \
# 0       1  NCT01095666  A Phase III Study of BMS-512148 (Dapagliflozin...
# 1       2  NCT01095653  A Phase III Study of BMS-512148 (Dapagliflozin...
# 2       3  NCT00683878         Add-on to Thiazolidinedione (TZD) Failures
# 3       4  NCT00643851  An Efficacy & Safety Study of BMS-512148 in Co...
# 4       5  NCT03836677  A Study to Evaluate the Effects of BGF and GFF...
# ..    ...          ...                                                ...
# 272   273  NCT00880919  Seroquel Extended Release (XR) for the Managem...
# 273   274  NCT01813435  GLOBAL LEADERS: A Clinical Study Comparing Two...
# 274   275  NCT00588406  Study of Budesonide as an Addition to Standard...
# 275   276  NCT00193596  Gemcitabine/Irinotecan/ZD1839 vs Paclitaxel/Ca...
# 276   277  NCT01248416  Aromatase Inhibitors, Alone And In Combination...
#
#         Acronym     Status Study Results  \
# ...

# %%
dates = data['Completion Date']
dates = np.array(dates)
dates_o = [datetime.datetime.strptime(x, '%B %Y') for x in dates if ',' not in x]
#dates_o = [datetime.datetime.strptime(x, '%B %d, %Y') for x in dates if ',' in x]
dates_o.sort()

# %%
print(dates_o)
# Out:
# [datetime.datetime(2007, 12, 1, 0, 0), datetime.datetime(2007, 12, 1, 0, 0), datetime.datetime(2007, 12, 1, 0, 0), datetime.datetime(2008, 1, 1, 0, 0), datetime.datetime(2008, 2, 1, 0, 0), datetime.datetime(2008, 2, 1, 0, 0), datetime.datetime(2008, 2, 1, 0, 0), datetime.datetime(2008, 2, 1, 0, 0), datetime.datetime(2008, 2, 1, 0, 0), datetime.datetime(2008, 3, 1, 0, 0), datetime.datetime(2008, 4, 1, 0, 0), datetime.datetime(2008, 4, 1, 0, 0), datetime.datetime(2008, 4, 1, 0, 0), datetime.datetime(2008, 4, 1, 0, 0), datetime.datetime(2008, 4, 1, 0, 0), datetime.datetime(2008, 4, 1, 0, 0), datetime.datetime(2008, 4, 1, 0, 0), datetime.datetime(2008, 4, 1, 0, 0), datetime.datetime(2008, 5, 1, 0, 0), datetime.datetime(2008, 6, 1, 0, 0), datetime.datetime(2008, 6, 1, 0, 0), datetime.datetime(2008, 6, 1, 0, 0), datetime.datetime(2008, 7, 1, 0, 0), datetime.datetime(2008, 7, 1, 0, 0), datetime.datetime(2008, 7, 1, 0, 0), datetime.datetime(2008, 7, 1, 0, 0), datetime.datetime(2008, 7, 1, 0,
# ...
